# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from lg2var3 import *

# %%
totalStep = 100
kwords = {'dstT':0.3, 'totalStep':totalStep, 'varzero':False, 'pbC':0.05, 'npts':200, 'multires':False, 'series':vanderpol}
res = gen_series(rrange(), rrange(), 0, logData = False, retVar = True, **kwords)
x = res[:,0]
y = res[:,1]
z = res[:,2]

xt = res[:,0] + 3
yt = res[:,1] - 2
zt = res[:,2] + 0.4

# %%
ax = plt.axes(projection='3d')
ax.plot3D(x, y, z)
ax.plot3D(xt, yt, zt)
